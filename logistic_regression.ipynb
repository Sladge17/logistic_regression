# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv('datasets/dataset_train.csv')
df_test = pd.read_csv('datasets/dataset_test.csv')

# %%
df_train.head()
# Out:
#    Index Hogwarts House First Name  Last Name    Birthday Best Hand  \
# 0      0      Ravenclaw     Tamara        Hsu  2000-03-30      Left
# 1      1      Slytherin      Erich    Paredes  1999-10-14     Right
# 2      2      Ravenclaw   Stephany      Braun  1999-11-03      Left
# 3      3     Gryffindor      Vesta  Mcmichael  2000-08-19      Left
# 4      4     Gryffindor     Gaston      Gibbs  1998-09-27      Left
#
#    Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# 0     58384.0 -487.886086   5.727180                       4.878861
# 1     67239.0 -552.060507  -5.987446                       5.520605
# 2     23702.0 -366.076117   7.725017                       3.660761
# 3     32667.0  697.742809  -6.497214                      -6.977428
# 4     60158.0  436.775204  -7.820623                            NaN
#
#    Divination  Muggle Studies  Ancient Runes  History of Magic  \
# 0       4.722      272.035831     532.484226          5.231058
# ...

# %%
df_train.describe()
# Out:
#             Index     Arithmancy    Astronomy    Herbology  \
# count  1600.00000    1566.000000  1568.000000  1567.000000
# mean    799.50000   49634.570243    39.797131     1.141020
# std     462.02453   16679.806036   520.298268     5.219682
# min       0.00000  -24370.000000  -966.740546   -10.295663
# 25%     399.75000   38511.500000  -489.551387    -4.308182
# 50%     799.50000   49013.500000   260.289446     3.469012
# 75%    1199.25000   60811.250000   524.771949     5.419183
# max    1599.00000  104956.000000  1016.211940    11.612895
#
#        Defense Against the Dark Arts   Divination  Muggle Studies  \
# count                    1569.000000  1561.000000     1565.000000
# mean                       -0.387863     3.153910     -224.589915
# std                         5.212794     4.155301      486.344840
# min                       -10.162119    -8.727000    -1086.496835
# 25%                        -5.259095     3.099000     -577.580096
# ...

# %%
df_test.head()
# Out:
#    Index  Hogwarts House First Name    Last Name    Birthday Best Hand  \
# 0      0             NaN       Rico      Sargent  2001-10-06     Right
# 1      1             NaN     Tamara  Shackelford  1998-01-08      Left
# 2      2             NaN      Staci     Crandall  1998-09-15      Left
# 3      3             NaN        Dee        Gavin  2001-05-10     Right
# 4      4             NaN    Gregory    Gustafson  1999-02-01     Right
#
#    Arithmancy   Astronomy  Herbology  Defense Against the Dark Arts  \
# 0     41642.0  696.096071   3.020172                      -6.960961
# 1     45352.0 -370.844655   2.965226                       3.708447
# 2     43502.0  320.303990  -6.185697                      -3.203040
# 3     61831.0  407.202928   4.962442                            NaN
# 4         NaN  288.337747   3.737656                      -2.883377
#
#    Divination  Muggle Studies  Ancient Runes  History of Magic  \
# ...

# %%
df_test.describe()
# Out:
#             Index  Hogwarts House    Arithmancy   Astronomy   Herbology  \
# count  400.000000             0.0    387.000000  387.000000  389.000000
# mean   199.500000             NaN  50088.971576   48.155326    1.385517
# std    115.614301             NaN  15472.748364  512.537781    5.055295
# min      0.000000             NaN   4536.000000 -802.725180   -9.687662
# 25%     99.750000             NaN  40167.500000 -483.719690   -4.183731
# 50%    199.500000             NaN  49238.000000  292.108738    3.630490
# 75%    299.250000             NaN  60157.000000  508.713093    5.405685
# max    399.000000             NaN  99744.000000  870.063498    9.678462
#
#        Defense Against the Dark Arts  Divination  Muggle Studies  \
# count                     392.000000  394.000000      390.000000
# mean                       -0.537843    3.411071     -220.169594
# std                         5.118762    3.891192      497.668782
# ...

# %%
Ravenclaw = df_train[df_train['Hogwarts House'] == 'Ravenclaw'].drop(['Index', 'Hogwarts House', 'First Name', 'Last Name', 'Birthday', 'Best Hand'], axis=1)
Slytherin = df_train[df_train['Hogwarts House'] == 'Slytherin'].drop(['Index', 'Hogwarts House', 'First Name', 'Last Name', 'Birthday', 'Best Hand'], axis=1)
Gryffindor = df_train[df_train['Hogwarts House'] == 'Gryffindor'].drop(['Index', 'Hogwarts House', 'First Name', 'Last Name', 'Birthday', 'Best Hand'], axis=1)
Hufflepuff = df_train[df_train['Hogwarts House'] == 'Hufflepuff'].drop(['Index', 'Hogwarts House', 'First Name', 'Last Name', 'Birthday', 'Best Hand'], axis=1)

# %%
Ravenclaw_hist = Ravenclaw.describe().T['count'].tolist()
Slytherin_hist = Slytherin.describe().T['count'].tolist()
Gryffindor_hist = Gryffindor.describe().T['count'].tolist()
Hufflepuff_hist = Hufflepuff.describe().T['count'].tolist()

# Ravenclaw_hist = Ravenclaw.sum().tolist()
# Slytherin_hist = Slytherin.sum().tolist()
# Gryffindor_hist = Gryffindor.sum().tolist()
# Hufflepuff_hist = Hufflepuff.sum().tolist()

# %%
plt.figure(figsize=(15, 8))
x = np.arange(13)
plt.bar(range(len(Ravenclaw_hist)), Ravenclaw_hist, width=1, align='edge', color='blue', alpha=0.5)
plt.bar(range(len(Slytherin_hist)), Slytherin_hist, width=1, align='edge', color='green', alpha=0.5)
plt.bar(range(len(Gryffindor_hist)), Gryffindor_hist, width=1, align='edge', color='red', alpha=0.5)
plt.bar(range(len(Hufflepuff_hist)), Hufflepuff_hist, width=1, align='edge', color='orange', alpha=0.5)
plt.xticks(x, ['ARI', 'AST', 'HER', 'DADA', 'DIV', 'MS',
                'AR', 'HM', 'TRA', 'POT', 'CMC', 'CHA', 'FLY'])
plt.title('Students activity')
plt.xlabel('Hogwarts courses')
plt.ylabel('Number of students')
plt.legend(loc='upper left')
plt.show()

# %%
bins = 20

# %%
ArithmancyRavenclaw = Ravenclaw['Arithmancy'].dropna()
ArithmancySlytherin = Slytherin['Arithmancy'].dropna()
ArithmancyGryffindor = Gryffindor['Arithmancy'].dropna()
ArithmancyHufflepuff = Hufflepuff['Arithmancy'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(ArithmancyRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(ArithmancySlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(ArithmancyGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(ArithmancyHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Arithmancy')
plt.xlabel('score')
plt.ylabel('amount')
plt.legend(loc='upper left')
plt.show()

# %%
AstronomyRavenclaw = Ravenclaw['Astronomy'].dropna()
AstronomySlytherin = Slytherin['Astronomy'].dropna()
AstronomyGryffindor = Gryffindor['Astronomy'].dropna()
AstronomyHufflepuff = Hufflepuff['Astronomy'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(AstronomyRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(AstronomySlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(AstronomyGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(AstronomyHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Astronomy')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
HerbologyRavenclaw = Ravenclaw['Herbology'].dropna()
HerbologySlytherin = Slytherin['Herbology'].dropna()
HerbologyGryffindor = Gryffindor['Herbology'].dropna()
HerbologyHufflepuff = Hufflepuff['Herbology'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(HerbologyRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(HerbologySlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(HerbologyGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(HerbologyHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Herbology')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
DefenseRavenclaw = Ravenclaw['Defense Against the Dark Arts'].dropna()
DefenseSlytherin = Slytherin['Defense Against the Dark Arts'].dropna()
DefenseGryffindor = Gryffindor['Defense Against the Dark Arts'].dropna()
DefenseHufflepuff = Hufflepuff['Defense Against the Dark Arts'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(DefenseRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(DefenseSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(DefenseGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(DefenseHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Defense Against the Dark Arts')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
DivinationRavenclaw = Ravenclaw['Divination'].dropna()
DivinationSlytherin = Slytherin['Divination'].dropna()
DivinationGryffindor = Gryffindor['Divination'].dropna()
DivinationHufflepuff = Hufflepuff['Divination'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(DivinationRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(DivinationSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(DivinationGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(DivinationHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Divination')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
MuggleStudiesRavenclaw = Ravenclaw['Muggle Studies'].dropna()
MuggleStudiesSlytherin = Slytherin['Muggle Studies'].dropna()
MuggleStudiesGryffindor = Gryffindor['Muggle Studies'].dropna()
MuggleStudiesHufflepuff = Hufflepuff['Muggle Studies'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(MuggleStudiesRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(MuggleStudiesSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(MuggleStudiesGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(MuggleStudiesHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Muggle Studies')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
AncientRunesRavenclaw = Ravenclaw['Ancient Runes'].dropna()
AncientRunesSlytherin = Slytherin['Ancient Runes'].dropna()
AncientRunesGryffindor = Gryffindor['Ancient Runes'].dropna()
AncientRunesHufflepuff = Hufflepuff['Ancient Runes'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(AncientRunesRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(AncientRunesSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(AncientRunesGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(AncientRunesHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Ancient Runes')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
HistoryRavenclaw = Ravenclaw['History of Magic'].dropna()
HistorySlytherin = Slytherin['History of Magic'].dropna()
HistoryGryffindor = Gryffindor['History of Magic'].dropna()
HistoryHufflepuff = Hufflepuff['History of Magic'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(HistoryRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(HistorySlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(HistoryGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(HistoryHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('History of Magic')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
TransfigurationRavenclaw = Ravenclaw['Transfiguration'].dropna()
TransfigurationSlytherin = Slytherin['Transfiguration'].dropna()
TransfigurationGryffindor = Gryffindor['Transfiguration'].dropna()
TransfigurationHufflepuff = Hufflepuff['Transfiguration'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(TransfigurationRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(TransfigurationSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(TransfigurationGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(TransfigurationHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Transfiguration')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
PotionsRavenclaw = Ravenclaw['Potions'].dropna()
PotionsSlytherin = Slytherin['Potions'].dropna()
PotionsGryffindor = Gryffindor['Potions'].dropna()
PotionsHufflepuff = Hufflepuff['Potions'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(PotionsRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(PotionsSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(PotionsGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(PotionsHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Potions')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
CreaturesRavenclaw = Ravenclaw['Care of Magical Creatures'].dropna()
CreaturesSlytherin = Slytherin['Care of Magical Creatures'].dropna()
CreaturesGryffindor = Gryffindor['Care of Magical Creatures'].dropna()
CreaturesHufflepuff = Hufflepuff['Care of Magical Creatures'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(CreaturesRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(CreaturesSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(CreaturesGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(CreaturesHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Care of Magical Creatures')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
CharmsRavenclaw = Ravenclaw['Charms'].dropna()
CharmsSlytherin = Slytherin['Charms'].dropna()
CharmsGryffindor = Gryffindor['Charms'].dropna()
CharmsHufflepuff = Hufflepuff['Charms'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(CharmsRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(CharmsSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(CharmsGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(CharmsHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Charms')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()

# %%
FlyingRavenclaw = Ravenclaw['Flying'].dropna()
FlyingSlytherin = Slytherin['Flying'].dropna()
FlyingGryffindor = Gryffindor['Flying'].dropna()
FlyingHufflepuff = Hufflepuff['Flying'].dropna()
plt.figure(figsize=(15, 8))
plt.hist(FlyingRavenclaw, color='blue', alpha=0.5, bins=bins)
plt.hist(FlyingSlytherin, color='green', alpha=0.5, bins=bins)
plt.hist(FlyingGryffindor, color='red', alpha=0.5, bins=bins)
plt.hist(FlyingHufflepuff, color='orange', alpha=0.5, bins=bins)
plt.title('Flying')
plt.xlabel('score')
plt.ylabel('amount')
plt.show()
