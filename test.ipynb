# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
column = ['name', 'numb1', 'numb2']
string1 = ['Ivan', 12, 4567]
string2 = ['Petr', 18, 1245]

df = pd.DataFrame([string1, string2], columns=column)
df.set_index('name', inplace=True)
df
# Out:
#       numb1  numb2
# name
# Ivan     12   4567
# Petr     18   1245

# %%
list(df.loc['Ivan'])
# Out:
# [12, 4567]

# %%
plt.figure(figsize=(15, 8))
plt.bar(range(len(list(df.loc['Ivan']))), list(df.loc['Ivan']))
plt.show()

# %%
df.index
# Out:
# Index(['Ivan', 'Petr'], dtype='object', name='name')

# %%
plt.figure(figsize=(15, 8))
plt.bar(range(2), [3,4], width=1, align='edge', color='red', alpha=0.5)
plt.bar(range(2), [3.5,2], width=1, align='edge', color='green', alpha=0.5)
plt.show()

# %%
# fig = plt.figure(figsize=(6, 4))
# ax = fig.add_subplot()
# x = [f'H{i+1}' for i in range(10)]
# y = np.random.randint(1, 5, len(x))
# ax.bar(x, y)

import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(6, 4))
ax = fig.add_subplot()
 
y = np.random.normal(0, 2, 500)
# print(dir(fig))
# ax.hist(y)
# ax.grid()
# plt.show()

# %%
q = np.arange(5)
q
# Out:
# array([0, 1, 2, 3, 4])

# %%
np.random.shuffle(q)
q
# Out:
# array([3, 2, 1, 0, 4])
